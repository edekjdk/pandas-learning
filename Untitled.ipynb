# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pokemon_df = pd.read_csv("./data/pokemon.csv")

# %%
pokemon_df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon_df.loc[(pokemon_df.Attack) > 50 & (pokemon_df.Defense < 80), ["Name", "Attack", "Defense"]]
# Out:
#                       Name  Attack  Defense
# 0                Bulbasaur      49       49
# 1                  Ivysaur      62       63
# 2                 Venusaur      82       83
# 3    VenusaurMega Venusaur     100      123
# 4               Charmander      52       43
# ..                     ...     ...      ...
# 795                Diancie     100      150
# 796    DiancieMega Diancie     160      110
# 797    HoopaHoopa Confined     110       60
# 798     HoopaHoopa Unbound     160       60
# 799              Volcanion     110      120
#
# [800 rows x 3 columns]

# %%
pokemon_df.groupby(["Generation"])["Attack"].mean()
# Out:
# Generation
# 1    76.638554
# 2    72.028302
# 3    81.625000
# 4    82.867769
# 5    82.066667
# 6    75.804878
# Name: Attack, dtype: float64

# %%
pokemon_df.loc[(pokemon_df.Legendary == True) & (pokemon_df.Generation == 1), ["Name", "Attack", "Defense", "Generation"]]
# Out:
#                     Name  Attack  Defense  Generation
# 156             Articuno      85      100           1
# 157               Zapdos      90       85           1
# 158              Moltres     100       90           1
# 162               Mewtwo     110       90           1
# 163  MewtwoMega Mewtwo X     190      100           1
# 164  MewtwoMega Mewtwo Y     150       70           1

# %%
pokemon_df.loc[(pokemon_df.Legendary == True) & (pokemon_df.Name.str.startswith("A")), ["Name", "Attack", "Defense", "Generation"]]
# Out:
#          Name  Attack  Defense  Generation
# 156  Articuno      85      100           1
# 539     Azelf     125       70           4
# 552    Arceus     120      120           4

# %%
pokemon_df.loc[(pokemon_df.Legendary == True)].groupby(["Generation"])["Name"].count()
# Out:
# Generation
# 1     6
# 2     5
# 3    18
# 4    13
# 5    15
# 6     8
# Name: Name, dtype: int64

# %%
pokemon_df.loc[(pokemon_df.Legendary == True)].groupby(["Generation"])["Attack"].mean()
# Out:
# Generation
# 1    120.833333
# 2     99.000000
# 3    118.333333
# 4    109.846154
# 5    120.266667
# 6    125.250000
# Name: Attack, dtype: float64

# %%
pokemon_df.loc[pokemon_df.groupby(["Type 1"])["Attack"].idxmax(), ["Type 1","Name", "Attack"]]
# Out:
#        Type 1                     Name  Attack
# 232       Bug  HeracrossMega Heracross     185
# 393      Dark          AbsolMega Absol     150
# 426    Dragon    RayquazaMega Rayquaza     180
# 517  Electric               Electivire     123
# 792     Fairy                  Xerneas     131
# 498  Fighting      LucarioMega Lucario     145
# 279      Fire    BlazikenMega Blaziken     160
# 702    Flying  TornadusIncarnate Forme     115
# 387     Ghost      BanetteMega Banette     165
# 511     Grass  AbomasnowMega Abomasnow     132
# 424    Ground    GroudonPrimal Groudon     180
# 524       Ice                Mamoswine     130
# 313    Normal                  Slaking     160
# 504    Poison                Toxicroak     106
# 163   Psychic      MewtwoMega Mewtwo X     190
# 454      Rock                Rampardos     165
# 750     Steel     AegislashBlade Forme     150
# 141     Water    GyaradosMega Gyarados     155

# %%
pokemon_df.loc[pokemon_df.groupby(["Type 1"])["Defense"].idxmax(), ["Type 1","Name", "Defense"]]
# Out:
#        Type 1                     Name  Defense
# 230       Bug                  Shuckle      230
# 327      Dark      SableyeMega Sableye      125
# 409    Dragon  SalamenceMega Salamence      130
# 513  Electric                Magnezone      115
# 519     Fairy                 Togekiss       95
# 256  Fighting                Hitmontop       95
# 355      Fire                  Torkoal      140
# 703    Flying    TornadusTherian Forme       80
# 624     Ghost               Cofagrigus      145
# 659     Grass               Ferrothorn      131
# 424    Ground    GroudonPrimal Groudon      160
# 789       Ice                  Avalugg      184
# 591    Normal        AudinoMega Audino      126
# 118    Poison                  Weezing      120
# 430   Psychic      DeoxysDefense Forme      160
# 414      Rock                 Regirock      200
# 224     Steel      SteelixMega Steelix      230
# 87      Water      SlowbroMega Slowbro      180

# %%
total = pokemon_df.loc[pokemon_df.groupby(["Type 1"])["Total"].idxmax(), ["Type 1","Name", "Total"]]
total
# Out:
#        Type 1                     Name  Total
# 137       Bug        PinsirMega Pinsir    600
# 793      Dark                  Yveltal    680
# 426    Dragon    RayquazaMega Rayquaza    780
# 196  Electric    AmpharosMega Ampharos    610
# 792     Fairy                  Xerneas    680
# 498  Fighting      LucarioMega Lucario    625
# 270      Fire                    Ho-oh    680
# 702    Flying  TornadusIncarnate Forme    580
# 544     Ghost    GiratinaAltered Forme    680
# 275     Grass    SceptileMega Sceptile    630
# 424    Ground    GroudonPrimal Groudon    770
# 156       Ice                 Articuno    580
# 552    Normal                   Arceus    720
# 183    Poison                   Crobat    535
# 163   Psychic      MewtwoMega Mewtwo X    780
# 268      Rock  TyranitarMega Tyranitar    700
# 413     Steel  MetagrossMega Metagross    700
# 422     Water      KyogrePrimal Kyogre    770

# %%
total.loc[total.Total.idxmax(), "Name"]
# Out:
# 'RayquazaMega Rayquaza'

# %%
pokemon_df.loc[pokemon_df.groupby(["Generation"])["Attack"].idxmax(), ["Generation","Name","Attack" ]]
# Out:
#      Generation                     Name  Attack
# 163           1      MewtwoMega Mewtwo X     190
# 232           2  HeracrossMega Heracross     185
# 424           3    GroudonPrimal Groudon     180
# 494           4    GarchompMega Garchomp     170
# 711           5       KyuremBlack Kyurem     170
# 796           6      DiancieMega Diancie     160

# %%
pokemon_df.loc[pokemon_df.groupby(["Generation"])["Defense"].idxmax(), ["Generation","Name","Defense" ]]
# Out:
#      Generation                 Name  Defense
# 87            1  SlowbroMega Slowbro      180
# 224           2  SteelixMega Steelix      230
# 333           3    AggronMega Aggron      230
# 456           4            Bastiodon      168
# 624           5           Cofagrigus      145
# 789           6              Avalugg      184

# %%
pokemon_df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
pokemon_df.loc[:, "Type 1"].unique()
p = pokemon_df["Type 1"].unique()
p.sort()
p
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
pokemon_df.loc[pokemon_df["Type 1"] == "Fire", ["Name", "Attack"]]
# Out:
#                           Name  Attack
# 4                   Charmander      52
# 5                   Charmeleon      64
# 6                    Charizard      84
# 7    CharizardMega Charizard X     130
# 8    CharizardMega Charizard Y     104
# 42                      Vulpix      41
# 43                   Ninetales      76
# 63                   Growlithe      70
# 64                    Arcanine     110
# 83                      Ponyta      85
# 84                    Rapidash     100
# 135                     Magmar      95
# 147                    Flareon     130
# 158                    Moltres     100
# 169                  Cyndaquil      52
# 170                    Quilava      64
# 171                 Typhlosion      84
# 236                     Slugma      40
# 237                   Magcargo      50
# 259                      Magby      75
# 263                      Entei     115
# 270                      Ho-oh     130
# 276                    Torchic      60
# ...

# %%
pokemon_df.groupby(["Type 1"])["Total"].mean()
# Out:
# Type 1
# Bug         378.927536
# Dark        445.741935
# Dragon      550.531250
# Electric    443.409091
# Fairy       413.176471
# Fighting    416.444444
# Fire        458.076923
# Flying      485.000000
# Ghost       439.562500
# Grass       421.142857
# Ground      437.500000
# Ice         433.458333
# Normal      401.683673
# Poison      399.142857
# Psychic     475.947368
# Rock        453.750000
# Steel       487.703704
# Water       430.455357
# Name: Total, dtype: float64

# %%
pokemon_df.loc[(pokemon_df.Legendary == True)&(pokemon_df.Total > 600)]
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 162  150                 Mewtwo  Psychic       NaN    680  106     110
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 269  249                  Lugia  Psychic    Flying    680  106      90
# 270  250                  Ho-oh     Fire    Flying    680  106     130
# 418  380      LatiasMega Latias   Dragon   Psychic    700   80     100
# 420  381      LatiosMega Latios   Dragon   Psychic    700   80     130
# 421  382                 Kyogre    Water       NaN    670  100     100
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 423  383                Groudon   Ground       NaN    670  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# 425  384               Rayquaza   Dragon    Flying    680  105     150
# ...

# %%
pokemon_df.insert(12, "Attack/Defense", value = pokemon_df.Attack / pokemon_df.Defense)

# %%
pokemon_df.drop(columns = ["Attack/Defense"], inplace = True)

# %%
pokemon_df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon_df.insert(len(pokemon_df.columns), "Attack/Defense", value = pokemon_df.Attack / pokemon_df.Defense)

# %%
pokemon_df.drop(columns = ["Attack/Defense"], inplace = True)

# %%
pokemon_df.insert(len(pokemon_df.columns), "Attack/Defense", value = round(pokemon_df.Attack / pokemon_df.Defense, 3))

# %%
pokemon_df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
attack = pokemon_df.loc[pokemon_df.groupby(["Generation"])["Attack"].idxmax(), ["Generation", "Name", "Attack"]]

# %%
speed = pokemon_df.groupby(["Generation"])["Speed"].mean().round(2)

# %%
comb = pd.merge(attack, speed, on = "Generation")

# %%
comb
# Out:
#    Generation                     Name  Attack  Speed
# 0           1      MewtwoMega Mewtwo X     190  72.58
# 1           2  HeracrossMega Heracross     185  61.81
# 2           3    GroudonPrimal Groudon     180  66.92
# 3           4    GarchompMega Garchomp     170  71.34
# 4           5       KyuremBlack Kyurem     170  68.08
# 5           6      DiancieMega Diancie     160  66.44

# %%
comb.columns = ["Generation", "Strongest Pokemon", "Attack", "Gen avg speed"]
comb
# Out:
#    Generation        Strongest Pokemon  Attack  Gen avg speed
# 0           1      MewtwoMega Mewtwo X     190          72.58
# 1           2  HeracrossMega Heracross     185          61.81
# 2           3    GroudonPrimal Groudon     180          66.92
# 3           4    GarchompMega Garchomp     170          71.34
# 4           5       KyuremBlack Kyurem     170          68.08
# 5           6      DiancieMega Diancie     160          66.44
