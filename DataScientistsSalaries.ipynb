# %%
import pandas as pd

# %%
ds_salaries = pd.read_csv("./data/DataScience_salaries_2025.csv", usecols = ["work_year", "experience_level", "job_title", "salary_in_usd","company_location", "company_size" ])

# %%
ds_salaries
# Out:
#        work_year experience_level                 job_title  salary_in_usd  \
# 0           2025               MI        Research Scientist         208000
# 1           2025               MI        Research Scientist         147000
# 2           2025               SE        Research Scientist         173000
# 3           2025               SE        Research Scientist         117000
# 4           2025               MI               AI Engineer         100000
# ...          ...              ...                       ...            ...
# 93592       2020               SE            Data Scientist         412000
# 93593       2021               MI  Principal Data Scientist         151000
# 93594       2020               EN            Data Scientist         105000
# 93595       2020               EN     Business Data Analyst         100000
# 93596       2021               SE            Data Scientist          94665
#
#       company_location company_size
# 0                   US            M
# 1                   US            M
# 2                   US            M
# 3                   US            M
# 4                   US            M
# ...                ...          ...
# 93592               US            L
# 93593               US            L
# 93594               US            S
# 93595               US            L
# 93596               IN            L
#
# [93597 rows x 6 columns]

# %%
ds_salaries.monthly_salary = ds_salaries.monthly_salary.round(2)

# %%
ds_salaries
# Out:
#        work_year experience_level                 job_title  salary_in_usd  \
# 0           2025               MI        Research Scientist         208000
# 1           2025               MI        Research Scientist         147000
# 2           2025               SE        Research Scientist         173000
# 3           2025               SE        Research Scientist         117000
# 4           2025               MI               AI Engineer         100000
# ...          ...              ...                       ...            ...
# 93592       2020               SE            Data Scientist         412000
# 93593       2021               MI  Principal Data Scientist         151000
# 93594       2020               EN            Data Scientist         105000
# 93595       2020               EN     Business Data Analyst         100000
# 93596       2021               SE            Data Scientist          94665
#
#        monthly_salary company_location company_size
# 0            17333.33               US            M
# 1            12250.00               US            M
# 2            14416.67               US            M
# 3             9750.00               US            M
# 4             8333.33               US            M
# ...               ...              ...          ...
# 93592        34333.33               US            L
# 93593        12583.33               US            L
# 93594         8750.00               US            S
# 93595         8333.33               US            L
# 93596         7888.75               IN            L
#
# [93597 rows x 7 columns]

# %%
ds_salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93597 entries, 0 to 93596
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   work_year         93597 non-null  int64
#  1   experience_level  93597 non-null  object
#  2   job_title         93597 non-null  object
#  3   salary_in_usd     93597 non-null  int64
#  4   monthly_salary    93597 non-null  float64
#  5   company_location  93597 non-null  object
#  6   company_size      93597 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 5.0+ MB

# %%
mean_salary = ds_salaries.monthly_salary.mean().round(2)
mean_salary
# Out:
# 13128.97

# %%
min_salary = ds_salaries.monthly_salary.min()
min_salary
# Out:
# 1250.0

# %%
max_salary = ds_salaries.monthly_salary.max()
max_salary
# Out:
# 66666.67

# %%
ds_salaries.company_location.value_counts()
# Out:
# company_location
# US    84347
# CA     3416
# GB     2670
# AU      317
# DE      282
#       ...
# MU        1
# GI        1
# OM        1
# ZM        1
# MD        1
# Name: count, Length: 90, dtype: int64

# %%
ds_pol = ds_salaries.query("company_location == 'PL'")
ds_us = ds_salaries.query("company_location == 'US'")

# %%
us_mean_salary = ds_us.salary_in_usd.mean().round(2)
pol_mean_salary = ds_pol.salary_in_usd.mean().round(2)

print("Mean salary in USA: {}, mean salary in Poland: {}".format(us_mean_salary, pol_mean_salary))
# Out:
# Mean salary in USA: 163452.12, mean salary in Poland: 78797.66

# %%
percentage = round((us_mean_salary - pol_mean_salary)/pol_mean_salary * 100,2)

# %%
print("{}%".format(percentage))
# Out:
# 107.43%
